# %% [markdown]
# # 使用PCA对人脸图片进行处理
#
# 此部分作业要求使用PCA技术对给定的人脸数据集进行处理，你需要在该文件中完成你的代码，并输出结果。
#
#
#
# 本次使用到的人脸数据集是 ORL人脸数据集，共包含40个不同人的400张图像。此数据集下包含40个目录，每个目录下有10张图像，每个目录表示一个不同的人。所有的图像是以PGM格式存储，灰度图，图像大小宽度为92，高度为112。
#
#
#
# 数据集中部分图像示例：
#
# ![image-20230428112024592](./faces.png)
#
#
#
# 在本次作业中，你需要**按顺序**完成以下内容并且在该文件中**保留要求**的输出结果：
#
# 1. 将数据集划分为80%的训练集，20%的测试集，在训练集上使用PCA将特征维度降为100，即得到100个特征和其对应的特征向量，并使用训练得到的PCA将测试集维度也压缩到100，**输出：压缩后的训练集维度和测试集维度、经过PCA得到的特征向量维度**。
#
# 2. 得到100个特征向量后，**使用这些向量重建特征脸并输出**。示例：
#
#    ![image2](./feature.png)
#
# 3. 使用这100个特征和对应的特征向量，自行在训练集和测试集中**分别**选择**5张**人脸图片进行人脸重建并**输出对比图**。示例：
#
#    ![image2](./restore.png)
#
# 4. **输出**降维后**每个**新特征向量所占的信息量占原始数据总信息量的百分比，以及所有返回特征所携带的**信息量总和**是原始数据的多少；
#
# 5. **画出**特征个数和所携带信息数的曲线图，此处特征数**上限设置为150**，此处以150为示例：
#
#    ![image2](./information.png)
#
# 6.  保留特征数为150，得到的训练集每次保留前（n=n+1，n初值为1）个特征，分别训练一个KNN分类器，KNN分类器的参数*n_neighbors*为3，观察并验证测试集在使用其前n个特征时KNN分类的准确率。**注意：此处仅进行一次PCA**,输出：不同的特征保留数和准确率的曲线图。此处以*n_neighbors=5*为示例：
#
#    ![image2](./acc.png)
#
#    **本次作业严禁抄袭，一经发现严肃处理**
#
#
# #  附加题
#
# 若感兴趣，可以自行拍摄自己或舍友的人脸照片、或者其他较为简单且特征明显的数据集进行PCA操作。

# %%
# 本次作业你可能需要用到的包和函数

# %matplotlib inline
# 导入所需模块
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# plt显示灰度图片
def plt_show(img):
    plt.imshow(img,cmap='gray')
    plt.show()

# 读取一个文件夹下的所有图片，输入参数是文件名，返回文件地址列表
def read_directory(directory_name):
    faces_addr = []
    for filename in os.listdir(directory_name):
        faces_addr.append(directory_name + "/" + filename)
    return faces_addr

# %%
directory_name = './data'
images = []
labels = []
for filename in os.listdir(directory_name):
    for i in read_directory(directory_name + "/" + filename):
        image = cv2.imread(i, 0)
        vector = np.reshape(image, (image.shape[0] * image.shape[1]))
        images.append(vector)
        labels.append(filename)
images = np.array(images)
labels = np.array(labels)

train_images, test_images, train_labels, test_labels = train_test_split(images,labels, test_size=0.2)
train_mean = np.mean(train_images)
test_mean = np.mean(test_images)
train_zero_mean = train_images - train_mean
test_zero_mean = test_images - test_mean

pca = PCA(n_components=100)
train_pca = pca.fit_transform(train_zero_mean)
test_pca = pca.transform(test_zero_mean)

print("压缩后的训练集维度：", train_pca.shape)
print("压缩后的测试集维度：", test_pca.shape)
print("经过PCA得到的特征向量维度：", pca.components_.shape)

# for i in range(len(pca.components_)):
#     plt_show(np.reshape(pca.components_[i], (112, 92)))

train_reconstructed = pca.inverse_transform(train_pca) + train_mean
test_reconstructed = pca.inverse_transform(test_pca) + test_mean

# for i in range(5):
#     plt_show(np.reshape(train_images[i], (112, 92)))
#     plt_show(np.reshape(train_reconstructed[i], (112, 92)))
# for i in range(5):
#     plt_show(np.reshape(test_images[i], (112, 92)))
#     plt_show(np.reshape(test_reconstructed[i], (112, 92)))

print("降维后特征向量的信息量占比：")
print(pca.explained_variance_ratio_)
print("所有特征向量的信息量总和占比：")
print(pca.explained_variance_ratio_.sum())

plt.plot(range(100), np.cumsum(pca.explained_variance_ratio_))
plt.show()

score = []
print(train_mean.shape)
print((pca.inverse_transform(train_pca[:,0:2])).shape)
for i in range(100):
    knn = KNeighborsClassifier(n_neighbors=3)
    knn.fit(pca.inverse_transform(train_pca[:,0:i]) + train_mean, train_labels)

    score.append(knn.score(pca.inverse_transform(test_pca[:,0:i]) + test_mean, test_labels))

plt.plot(range(100), score)
# Out:
# 压缩后的训练集维度： (320, 100)
# 压缩后的测试集维度： (80, 100)
# 经过PCA得到的特征向量维度： (100, 10304)
# 降维后特征向量的信息量占比：
# [0.17834919 0.12384582 0.07023058 0.05416658 0.04935147 0.03465131
#  0.0254765  0.02447259 0.02071403 0.0191319  0.01526378 0.01422201
#  0.01143238 0.0107627  0.00978786 0.00908799 0.00889489 0.00856232
#  0.00749736 0.0073593  0.00686476 0.00674838 0.00608331 0.00555441
#  0.00521729 0.00517027 0.00495775 0.00489039 0.00478779 0.00448849
#  0.00438444 0.00436015 0.00418179 0.00402657 0.0038068  0.003646
#  0.00358124 0.00353279 0.00331255 0.00324441 0.00308551 0.00298979
#  0.00295698 0.00285212 0.00280623 0.00273088 0.00264266 0.00257204
#  0.00253665 0.00244921 0.00241442 0.00231722 0.00228639 0.00223333
#  0.00216343 0.0021571  0.00208809 0.00205883 0.0020088  0.00199424
#  0.00191419 0.00188226 0.00186062 0.00182888 0.00178601 0.00176155
#  0.00174073 0.00168785 0.00164819 0.00159997 0.00158187 0.00154413
#  0.00151735 0.00149843 0.0014851  0.00147163 0.0014547  0.00142538
# ...
